# %%
# changing the directory in which jupyter looks for our modules
import sys
import os
from os.path import dirname, abspath, join

cwd = dirname(os.getcwd())
code = abspath(join(cwd, 'tweetastrophy'))
sys.path.append(code)

# %%
pwd
# Out:
# '/Users/martin/code/cidamla/tweetastrophy_project/notebooks'

# %%
#!pip install streamlit-folium --quiet
#!pip install folium --quiet

# %%
from get_data import get_data
from preprocessing import preprocessing 
from location import creat_location
import pandas as pd


#import nltk
#nltk.download('maxent_ne_chunker')
#nltk.download('words')

#train_df, test_df = get_data(drop_location=True)
#train_df = preprocessing(train_df)
#train_df = creat_location(train_df)
df = creat_location("../tweetastrophy/tweets.text")
df
# Out:
# 2022-12-02 15:51:37.218042: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/martin/code/cidamla/tweetastrophy_project/tweetastrophy/location.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lat'].iloc[x], df['lon'].iloc[x] = (extract_gps(y['country'],y['city']))
#                                                  text     region  \
# 0   ⚡️ Fuel depot caught fire in Surazh district o...    Unknown
# 1   On March 30, 2022, the Islamic regime prevente...    Unknown
# 2   New aerial video captures eruption of world’s ...     Hawaii
# 3   Immerse yourself in culture in the beautiful c...    Unknown
# 4   Algeria court sentences 49 to death over fores...    Unknown
# 5   I am praying for the people of #Indonesia, who...    Unknown
# 6   🔴 Torrential downpour in #Jeddah right now, ur...    Unknown
# 7   Powerful flooding in #SaudiArabia Heavy rain h...    Unknown
# 8   Who heard that loud noise in North London? #ex...    Unknown
# 9   Green #earthquake alert (4.7M,depth:17.978km) ...    Unknown
# 10  Mock rescue drill post a train accident done o...  Karnataka
# 11  BREAKING: Two military planes collided and cra...    Unknown
# 12  WATCH: #BNNArgentina Reports A new forest fire...    Unknown
# 13  The fire is very large-scale, there is a threa...    Unknown
# 14                                                 \n    Unknown
# 15                                                 \n    Unknown
# 16                                                 \n    Unknown
# 17  In Russia there is a large fire blazing near t...     Moscow
# 18                                                 \n    Unknown
# 19                                                 \n    Unknown
# 20                                                 \n    Unknown
# 21  ⚡️Russia strikes maternity ward in Zaporizhzhi...    Unknown
# 22                                                 \n    Unknown
# 23                                                 \n    Unknown
# 24                                                 \n    Unknown
# 25  Israeli forces killed 2 Palestinians in the oc...  West Bank
# 26                                                 \n    Unknown
# 27                                                 \n    Unknown
# 28                                                 \n    Unknown
# 29                                                 \n    Unknown
# 30  ⚠️ TAIWAN 🇹🇼 BRUTAL MOTORCYCLE ACCIDENT RESULT...     Taiwan
# 31                                                 \n    Unknown
# 32                                                 \n    Unknown
# 33                                                 \n    Unknown
# 34  JUST IN: 1 dead after motorcycle accident in C...    Unknown
# 35                                                 \n    Unknown
#
#                       country      city        lat         lon
# 0          Russian Federation   Bryansk  53.242378   34.366829
# 1                       Qatar     March  48.057857    7.779004
# 2               United States   Unknown  39.783730 -100.445882
# 3                     Germany    Calais  50.952477    1.853845
# 4                     Algeria   Unknown  28.000027    2.999983
# 5                   Indonesia   Unknown  -2.483383  117.890285
# 6                Saudi Arabia    Jeddah  21.581009   39.165361
# 7                Saudi Arabia    Jeddah  21.581009   39.165361
# 8                     Unknown   Unknown  25.029422  -77.361956
# 9                       Tonga     Green  37.243398  -85.534630
# 10                      India   Unknown  22.351115   78.667743
# 11              United States    Dallas  32.776272  -96.796856
# 12                    Unknown   Unknown  25.029422  -77.361956
# 13         Russian Federation      Tver  56.858675   35.920828
# 14                    Unknown   Unknown  25.029422  -77.361956
# 15                    Unknown   Unknown  25.029422  -77.361956
# 16                    Unknown   Unknown  25.029422  -77.361956
# 17                    Ukraine    Moscow  55.750446   37.617494
# 18                    Unknown   Unknown  25.029422  -77.361956
# 19                    Unknown   Unknown  25.029422  -77.361956
# 20                    Unknown   Unknown  25.029422  -77.361956
# 21              United States    Russia  64.686314   97.745306
# 22                    Unknown   Unknown  25.029422  -77.361956
# 23                    Unknown   Unknown  25.029422  -77.361956
# 24                    Unknown   Unknown  25.029422  -77.361956
# 25        Palestine, State of   Unknown   0.000000    0.000000
# 26                    Unknown   Unknown  25.029422  -77.361956
# 27                    Unknown   Unknown  25.029422  -77.361956
# 28                    Unknown   Unknown  25.029422  -77.361956
# 29                    Unknown   Unknown  25.029422  -77.361956
# 30  Taiwan, Province of China   Unknown   0.000000    0.000000
# 31                    Unknown   Unknown  25.029422  -77.361956
# 32                    Unknown   Unknown  25.029422  -77.361956
# 33                    Unknown   Unknown  25.029422  -77.361956
# 34              United States  Crockett  30.651738 -101.376669
# 35                    Unknown   Unknown  25.029422  -77.361956

# %%
import folium
import streamlit as st
from streamlit_folium import st_folium

# creating basic map in folium
map = folium.Map(location=[df.lat.mean(), 
                           df.lon.mean()], 
                 tiles="cartodbpositron",
                 zoom_start=50, control_scale=True)


# mapping circles to df in DataFrame
for index, row in df.iterrows():
    # checking for rows without coordinates
    if row["lat"] == 0.0 or row["lon"] == 0.0:
        continue
    elif row["city"] != "Unknown":
        folium.CircleMarker(location=[row["lat"], row["lon"]], radius=10, popup=row["city"],
                            color="#EE4B2B", fill=True, fill_color="#EE4B2B").add_to(map) # red
    elif (row["region"] != "Unknown") & (row["city"] == "Unknown"):
        
        folium.CircleMarker(location=[row["lat"], row["lon"]], radius=20, popup=row["city"],
                            color="#90ee90", fill=True, fill_color="#90ee90").add_to(map) # green  
    elif (row["country"] != "Unknown") & (row["region"] == "Unknown") & (row["city"] == "Unknown"):
        folium.CircleMarker(location=[row["lat"], row["lon"]], radius=30, popup=row["country"],
                            color="#00008b", fill=True, fill_color="#00008b").add_to(map) # blue
             
            
# adding automatic zoom to last df
sw = df[['lat', 'lon']].min().values.tolist()
ne = df[['lat', 'lon']].max().values.tolist()

map.fit_bounds([sw, ne], padding=(1,1)) 

# render Folium map in Streamlit
#st_data = st_folium(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3987727a21168dbe3a5bcbea8613bf8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3987727a21168dbe3a5bcbea8613bf8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3987727a21168dbe3a5bcbea8613bf8b = L.map(
#                 &quot;map_3987727a21168dbe3a5bcbea8613bf8b&quot;,
#                 {
#                     center: [28.794224425, -37.80164337262137],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 50,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3987727a21168dbe3a5bcbea8613bf8b);
#
#
#
#
#
#             var tile_layer_9ef813f905508ac5b4df1fc8e686c191 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3987727a21168dbe3a5bcbea8613bf8b);
#
#
#             var circle_marker_563919076147b02130ed8839a984f081 = L.circleMarker(
#                 [53.2423778, 34.3668288],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE4B2B&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE4B2B&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3987727a21168dbe3a5bcbea8613bf8b);
#
#
#         var popup_651c37c9608898d66af303548604f2aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7f87552bf9373152a0694bf1f4b8a4f = $(`&lt;div id=&quot;html_e7f87552bf9373152a0694bf1f4b8a4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bryansk&lt;/div&gt;`)[0];
#                 popup_651c37c9608898d66af303548604f2aa.setContent(html_e7f87552bf9373152a0694bf1f4b8a4f);
#
#
#
#         circle_marker_563919076147b02130ed8839a984f081.bindPopup(popup_651c37c9608898d66af303548604f2aa)
#         ;
#
#
#
#
#             var circle_marker_08d3875889ae7f1a7829295cc4957ce6 = L.circleMarker(
#                 [48.0578573, 7.7790038],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE4B2B&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE4B2B&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3987727a21168dbe3a5bcbea8613bf8b);
#
#
#         var popup_4f2dc5a5f878f439450a79b614289618 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fe6f81efd467deee82a5ac68d8bddd9 = $(`&lt;div id=&quot;html_3fe6f81efd467deee82a5ac68d8bddd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;March&lt;/div&gt;`)[0];
#                 popup_4f2dc5a5f878f439450a79b614289618.setContent(html_3fe6f81efd467deee82a5ac68d8bddd9);
#
#
#
#         circle_marker_08d3875889ae7f1a7829295cc4957ce6.bindPopup(popup_4f2dc5a5f878f439450a79b614289618)
#         ;
#
#
#
#
#             var circle_marker_f395d9ba6fd2475cbeb5bc76c19147f5 = L.circleMarker(
#                 [39.7837304, -100.445882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#90ee90&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#90ee90&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3987727a21168dbe3a5bcbea8613bf8b);
#
#
#         var popup_d05be9db8b47d3bbb4e47f88ac88a15c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29a4cc2f7f48d1841ba23f75c39a11d2 = $(`&lt;div id=&quot;html_29a4cc2f7f48d1841ba23f75c39a11d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Unknown&lt;/div&gt;`)[0];
#                 popup_d05be9db8b47d3bbb4e47f88ac88a15c.setContent(html_29a4cc2f7f48d1841ba23f75c39a11d2);
#
#
#
#         circle_marker_f395d9ba6fd2475cbeb5bc76c19147f5.bindPopup(popup_d05be9db8b47d3bbb4e47f88ac88a15c)
#         ;
#
#
#
#
#             var circle_marker_07dac020afc7a5b6521c5024b1005652 = L.circleMarker(
#                 [50.9524769, 1.8538446],
#                 {&quot;bubblingMouseEvents&quot;: true, &q
